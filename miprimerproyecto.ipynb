# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielParada01/Progralll-SemiPresencial2026/blob/main/miprimerproyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(booleano)

# %%
print("Sumar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))
print("Respueta: ", respuesta[0:2])

respuesta = "suma completa"
# Out:
# Sumar dos numeros:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1593/3175090164.py in <cell line: 0>()
#       1 print("Sumar dos numeros: ")
# ----> 2 num1 = input("Num 1: ")
#       3 num2 = input("Num 2: ")
#       4 respuesta = float(num1) + float(num2)
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
saludo = "hola chicos de progra"
print("primer Elemento de la cadena", saludo[0])
print("Rango en una cadena", saludo[0:4])
print("Ultimo elemento", saludo [-1])
print("Ultimo Elemento", saludo[1en(saludo)-1])
print("Valor en medio sin especificar ultimo valor", saludo[5:])
print("Sin Valor al inicio", saludo[0:4])
print("Contar desde el final", saludo[5:-1])

# %%
def suma (num1, num2):
  respuesta = float(num1) +float(num2)
  return respuesta

# %%
def suma (num1, num2):
  respuesta = float(num1) - float(num2)
  return respuesta

# %%
def convertir(celcius):
  return float(celcius)*9/5 + 32

# %%
def convertir(celcius):
  return float(celcius)*9/5 + 32
c = input("Grados Celcius: ")
print("Grados Farenheit:", convertir(c))

# %%
def convertir(Farenheit):
  return (float(Farenheit) - 32) * 5 / 9

# %%
f = input("Grados Farenheit: ")
print("Grados Celcius: ", convertir(f))

# %%
def convertir(kelvin):
  return float(kelvin) + 275.15

# %%
k = input("Grados kelvin: ")
print("Grados Celcius: ", convertir(k))

# %%
def convertir(celcius):
  return float(celcius) + 273.15

c = input("Ingresa los grados celciu: ")

print("Grados Kelvin: ", convertir(c))

# %% [markdown]
# Convertir de farenheit a celcius

# %%
def convertir (farenheit):
  return (float(farenheit)-32) * 5/9
f = input("Ingrese los grados farenheit: ")

print("Grados Celcius: ", convertir(f))
# Out:
# Ingrese los grados farenheit: 1
# Grados Celcius:  -17.22222222222222

# %% [markdown]
# Convertir de celcius a kelvin

# %%
def convertir(celcius):
  return float(celcius) + 273.15

c = input("Ingrese los grados celcius: ")

print("Grados Kelvin: ", convertir(c))
# Out:
# Ingrese los grados celcius: 1
# Grados Kelvin:  274.15

# %% [markdown]
# Elevar un numero a su exponente.

# %%
def elevar_al_cuadrado(numero):
  return float(numero) ** 2
num = input("Ingrese el numero")

print ("El numero elevado al cuadrado es: ", elevar_al_cuadrado(num))
# Out:
# Ingrese el numero5
# El numero elevado al cuadrado es:  25.0

# %%
# 1. Definimos la función del factorial
def calcular_factorial(numero):
    n = int(numero)  # El factorial solo funciona con enteros

    # Caso especial: el factorial de 0 y 1 siempre es 1
    if n == 0 or n == 1:
        return 1

    # Variable para ir acumulando el resultado de las multiplicaciones
    resultado = 1

    # Bucle que va desde 1 hasta 'n'
    for i in range(1, n + 1):
        resultado = resultado * i  # Multiplica acumulativamente

    return resultado

# 2. Pedimos el número al usuario
num = input("Ingrese un número entero para calcular su factorial: ")

# 3. Mostramos el resultado
print("El factorial de", num, "es:", calcular_factorial(num))
# Out:
# Ingrese un número entero para calcular su factorial: 7
# El factorial de 7 es: 5040

# %% [markdown]
# Calcular el suelo de un empleado. horas * valor de horas * 30 días, las deducciones:ISSS, AFP, ISR.

# %%
# 1. Definimos la función principal de cálculo
def calcular_planilla_sv(horas_diarias, valor_hora):
    # Convertimos los datos de entrada a números decimales
    h = float(horas_diarias)
    v = float(valor_hora)

    # --- SUELDO BRUTO ---
    sueldo_bruto = h * v * 30

    # --- DEDUCCIÓN ISSS (3% con techo de $30.00) ---
    isss = sueldo_bruto * 0.03
    if isss > 30.00:
        isss = 30.00

    # --- DEDUCCIÓN AFP (7.25%) ---
    afp = sueldo_bruto * 0.0725

    # --- BASE PARA EL IMPUESTO SOBRE LA RENTA (ISR) ---
    sueldo_imponible = sueldo_bruto - isss - afp

    # --- CÁLCULO DE ISR POR TRAMOS (Mensual) ---
    if sueldo_imponible <= 472.00:
        isr = 0.0
    elif sueldo_imponible <= 895.24:
        isr = ((sueldo_imponible - 472.00) * 0.10) + 17.67
    elif sueldo_imponible <= 2038.10:
        isr = ((sueldo_imponible - 895.24) * 0.20) + 60.00
    else: # Más de $2038.10
        isr = ((sueldo_imponible - 2038.10) * 0.30) + 288.57

    # --- SUELDO NETO (Lo que recibe en mano) ---
    total_deducciones = isss + afp + isr
    sueldo_neto = sueldo_bruto - total_deducciones

    #resultados detallados
    print("\n--- RESUMEN DE PLANILLA ---")
    print(f"Sueldo Bruto: ${sueldo_bruto:.2f}")
    print(f"(-) ISSS (3%): ${isss:.2f}")
    print(f"(-) AFP (7.25%): ${afp:.2f}")
    print(f"(-) ISR (Renta): ${isr:.2f}")
    print("----------------------------")
    print(f"Total Descuentos: ${total_deducciones:.2f}")
    print(f"SUELDO NETO A RECIBIR: ${sueldo_neto:.2f}")


#Pedimos los datos al usuario
horas = input("Ingrese la cantidad de horas trabajadas al día: ")
precio_hora = input("Ingrese el valor monetario de la hora ($): ")

# 3. Llamamos a la función
calcular_planilla_sv(horas, precio_hora)
